# %%
import pandas as pd

# %%
# Load the dataset, skipping the first column which is an unnecessary index

matches = pd.read_csv("matches.csv", index_col=0)

# %%
# Display the first few rows of the dataframe to verify it loaded correctly
matches.head()
# Out:
#          date           time          comp        round  day venue result gf  \
# 0  2024-08-10  12:30 (13:30)  Championship  Matchweek 1  Sat  Home      D  3
# 2  2024-08-17  12:30 (13:30)  Championship  Matchweek 2  Sat  Away      D  0
# 3  2024-08-23  20:00 (21:00)  Championship  Matchweek 3  Fri  Away      W  2
# 4  2024-08-31  15:00 (16:00)  Championship  Matchweek 4  Sat  Home      W  2
# 5  2024-09-14  12:30 (13:30)  Championship  Matchweek 5  Sat  Home      L  0
#
#   ga        opponent  ...  sh  sot  dist   fk pk pkatt xg_y npxg  \
# 0  3      Portsmouth  ...  21    9  16.6  1.0  1     1  3.3  2.5
# 2  0       West Brom  ...   8    1  20.3  0.0  0     0  0.7  0.7
# 3  0  Sheffield Weds  ...  13    5  18.4  1.0  0     0  1.2  1.2
# 4  0       Hull City  ...  16    5  17.6  1.0  0     0  1.5  1.5
# 5  1         Burnley  ...  17    4  18.4  0.0  0     0  1.2  1.2
#
#            team season
# 0  Leeds United   2025
# 2  Leeds United   2025
# 3  Leeds United   2025
# 4  Leeds United   2025
# 5  Leeds United   2025
#
# [5 rows x 30 columns]

# %%
# Display the shape of the dataframe to understand its dimensions
matches.shape
# Out:
# (10024, 30)

# %% [markdown]
# # Analyze Data

# %%
# Value counts will not be the same for all teams due to promotions and relegations in previous seasons.
matches["team"].value_counts()
# Out:
# team
# Bristol City                416
# Queens Park Rangers         414
# Preston North End           414
# Middlesbrough               372
# Cardiff City                370
# Blackburn Rovers            368
# Millwall                    368
# Birmingham City             368
# Derby County                327
# Swansea City                327
# Reading                     325
# Sheffield Wednesday         324
# Norwich City                324
# Hull City                   322
# Stoke City                  322
# Huddersfield Town           282
# Leeds United                281
# West Bromwich Albion        280
# Nottingham Forest           279
# Coventry City               235
# Luton Town                  235
# Brentford                   235
# Sheffield United            235
# Barnsley                    232
# Rotherham United            230
# Fulham                      192
# Sunderland                  189
# Ipswich Town                184
# Watford                     184
# Wigan Athletic              184
# Aston Villa                 144
# Bournemouth                  94
# Burnley                      92
# Burton Albion                92
# Blackpool                    92
# Plymouth Argyle              92
# Wolverhampton Wanderers      92
# Bolton Wanderers             91
# Southampton                  49
# Leicester City               46
# Oxford United                46
# Portsmouth                   46
# Peterborough United          46
# Wycombe Wanderers            46
# Charlton Athletic            46
# Newcastle United             46
# Brighton and Hove Albion     46
# Name: count, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1                          216
# Matchweek 2                          216
# Matchweek 3                          216
# Matchweek 4                          216
# Matchweek 5                          216
# Matchweek 6                          216
# Matchweek 7                          216
# Matchweek 8                          216
# Matchweek 9                          216
# Matchweek 10                         216
# Matchweek 11                         216
# Matchweek 12                         216
# Matchweek 13                         216
# Matchweek 14                         216
# Matchweek 15                         216
# Matchweek 16                         216
# Matchweek 17                         216
# Matchweek 18                         216
# Matchweek 19                         216
# Matchweek 20                         216
# Matchweek 21                         216
# Matchweek 22                         216
# Matchweek 23                         216
# Matchweek 24                         216
# Matchweek 25                         216
# Matchweek 26                         216
# Matchweek 27                         216
# Matchweek 28                         216
# Matchweek 29                         216
# Matchweek 30                         216
# Matchweek 31                         216
# Matchweek 32                         216
# Matchweek 33                         216
# Matchweek 34                         216
# Matchweek 35                         216
# Matchweek 36                         216
# Matchweek 37                         216
# Matchweek 38                         216
# Matchweek 39                         216
# Matchweek 40                         216
# Matchweek 41                         216
# Matchweek 42                         216
# Matchweek 43                         216
# Matchweek 44                         216
# Matchweek 46                         216
# Matchweek 45                         214
# Promotion play-offs — Semi-finals     72
# Promotion play-offs — Final           18
# Name: count, dtype: int64

# %% [markdown]
# # Cleaning Data

# %%
# Display the data types of each column to understand the structure of the dataframe

matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf                object
# ga                object
# opponent          object
# xg_x             float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes             object
# sh                 int64
# sot                int64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# xg_y             float64
# npxg             float64
# team              object
# season             int64
# dtype: object

# %%
# Delete unnecessary columns that will never be used in the analysis or model training

del matches["comp"]
del matches["notes"]

# %%
# Convert the 'date' type from object to datetime format so that it can be used by the model.

matches["date"] = pd.to_datetime(matches["date"])

# %%
# Create the target variable by using the result variable converted into a binary format so that it can be used by the model.

matches["target"] = (matches["result"] == "W").astype("int") # 1 for win, 0 for draw or loss

# %%
# Extract the first number (including negative numbers) from the string and convert the columns to integer type so that they can be used by the model.

matches["gf"] = matches["gf"].str.extract(r'(-?\d+)').astype("Int64") # Goals For
matches["ga"] = matches["ga"].str.extract(r'(-?\d+)').astype("Int64") # Goals Against

# %%
# Categorize the venue column and create a new column with the corresponding category codes so that it can be used by the model.

matches["venue_code"] = matches["venue"].astype("category").cat.codes # Home=1, Away=0

# %%
# Create a new code for each opponent team so that it can be used by the model.

matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
# Remove the colon and everything after it from the time column (or replacing with nothing), then convert the hour to an integer type so that it can be used by the model.

matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
# Generate a number for each day of the week (Monday=0, Sunday=6) from the date column so that it can be used by the model.

matches["day_code"]= matches["date"].dt.dayofweek

# %% [markdown]
# # Create the Machine Learning Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# A Random Forest is a type of model that can pick up non-linearities in the data.
#
# For example, our opponent code doesn't have a linear relationship. Having an opponent code of 10 instead of 2 doesn't mean that you're facing a tougher opponent. A linear model cannot see this.

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %% [markdown]
# ``n_estimators`` is the number of trees in the forest.
# This means that the model will create 50 different decision trees and combine their predictions to make a final prediction.
#
# ``min_samples_split`` is the minimum number of samples required to split an internal node.
# This means that a node must have at least 10 samples in order to be considered for splitting into two child nodes.
# The higher this number, the less likely the model is to overfit the training data, but it may also lead to underfitting if set too high.
#
# ``random_state`` is a seed value that ensures reproducibility of the results.

# %%
# Generate the training set by selecting all matches before 2025.

train = matches[matches["date"] < '2025-01-01']

# %%
# Generate the test set by selecting all matches in 2025 and beyond.

test = matches[matches["date"] >= '2025-01-01']

# %%
# Define the predictor variables that will be used to train the model.

predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
# Fit the Random Forest model using the training data and the defined predictor variable.

rf.fit(train[predictors], train["target"])

# We are telling the model to learn the relationship between the predictor variables and the target variable (win or not win).
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
# After fitting, we can make predictions based on the predictors in the test data.

preds = rf.predict(test[predictors])

# %% [markdown]
# # Measuring Model's Performance

# %%
from sklearn.metrics import accuracy_score

# %%
# Evaluate the model's accuracy by comparing the predicted values to the actual target values in the test set.

accuracy_score(test["target"], preds)
# Out:
# 0.5952380952380952

# %% [markdown]
# We get an **accuracy** score of **60%**
#
# Let's dig a little bit deeper to see when our accuracy was high versus when it was low.
#
# In order to do that we need to create a Pandas dataframe to combine our actual values and predicted values.

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           287  56
# 1           165  38

# %% [markdown]
# We can see that when predicting a loss or draw we are performing better than when we predict a win.
#
# Since predicting wins is what we are trying to do, we're going to change our performance metric from **accuracy** to **precision**.
#
# This will show us how often we were correct when we predicted a win.

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.40425531914893614

# %% [markdown]
# Our precision is only **40%**
#
# ## Rolling Averages
#
# In order to attempt to improve our performance we're going to create some more predictors.
#
# We'll start by splitting our dataframe up by team. This will allow us to calculate rolling averages for team performance.
#
# What is their recent form like?
#
# How did each team do in the past few games?
#
# How many shots did they have? How many shots were made against them?

# %%
# Create a dataframe for every team in our dataset.

grouped_matches = matches.groupby("team")

# %%
# Display one of the new dataframes to verify it worked. Using Hull City as an example.


hull = grouped_matches.get_group("Hull City").sort_values("date")

hull
# Out:
#          date           time         round  day venue result  gf  ga  \
# 0  2017-08-05  17:30 (18:30)   Matchweek 1  Sat  Away      D   1   1
# 1  2017-08-12  15:00 (16:00)   Matchweek 2  Sat  Home      W   4   1
# 2  2017-08-15  19:45 (20:45)   Matchweek 3  Tue  Home      L   2   3
# 3  2017-08-19  15:00 (16:00)   Matchweek 4  Sat  Away      L   1   2
# 5  2017-08-25  19:45 (20:45)   Matchweek 5  Fri  Home      W   4   0
# ..        ...            ...           ...  ...   ...    ...  ..  ..
# 44 2025-04-14  20:00 (21:00)  Matchweek 42  Mon  Home      D   1   1
# 45 2025-04-18  15:00 (16:00)  Matchweek 43  Fri  Away      L   0   1
# 46 2025-04-21  15:00 (16:00)  Matchweek 44  Mon  Home      W   2   1
# 47 2025-04-26  15:00 (16:00)  Matchweek 45  Sat  Home      L   0   1
# 48 2025-05-03  12:30 (13:30)  Matchweek 46  Sat  Away      D   1   1
#
#          opponent  xg_x  ...  pkatt  xg_y  npxg       team season target  \
# 0     Aston Villa   NaN  ...      0   NaN   NaN  Hull City   2018      0
# 1   Burton Albion   NaN  ...      0   NaN   NaN  Hull City   2018      1
# 2          Wolves   NaN  ...      1   NaN   NaN  Hull City   2018      0
# 3             QPR   NaN  ...      0   NaN   NaN  Hull City   2018      0
# 5          Bolton   NaN  ...      0   NaN   NaN  Hull City   2018      1
# ..            ...   ...  ...    ...   ...   ...        ...    ...    ...
# 44  Coventry City   1.0  ...      0   1.0   1.0  Hull City   2025      0
# 45   Swansea City   0.6  ...      0   0.6   0.6  Hull City   2025      0
# 46        Preston   2.1  ...      2   2.1   0.7  Hull City   2025      1
# 47   Derby County   0.4  ...      0   0.4   0.4  Hull City   2025      0
# 48     Portsmouth   2.2  ...      0   2.2   2.2  Hull City   2025      0
#
#    venue_code opp_code  hour  day_code
# 0           0        0    17         5
# 1           1       11    15         5
# 2           1       45    19         1
# 3           0       33    15         5
# 5           1        5    19         4
# ..        ...      ...   ...       ...
# 44          1       14    20         0
# 45          0       41    15         4
# 46          1       32    15         0
# 47          1       15    15         5
# 48          0       31    12         5
#
# [322 rows x 33 columns]

# %% [markdown]
# Using these new dataframes, if we're on matchweek 10 we want to ask how did they do in their last 6 previous weeks.
#
# Then we can pass that information into the model to be used to make better predictions.

# %%
# We create a function that will take in a group (a team's dataframe), the columns we want to calculate rolling averages for, and the names of the new columns to store those averages.

def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(6, closed="left").mean() # closed="left" ensures we don't include the current match in the average
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols) # Drop rows where the new columns have NaN values as Pandas cannot handle NaN values in the model
    return group

# %%
# We're going to calculate rolling averages for the following columns:

cols = ["gf", "ga", "xg_x", "xga", "sh", "sot", "dist", "fk", "pk", "pkatt"] # goals for, goals against, expected goals for, expected goals against, shots, shots on target, distance covered, free kicks, penalties scored, penalties attempted

# Now we columns for the rolling averages of each of the above columns.
new_cols = [f"{c}_rolling" for c in cols]

new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'xg_x_rolling',
#  'xga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
# Apply the rolling_averages function to each team's dataframe and combine the results into a single matches_rolling dataframe.

matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

matches_rolling
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_36452\1437904496.py:3: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
#                            date           time         round  day venue  \
# team
# Aston Villa       8  2018-09-15  17:30 (18:30)   Matchweek 7  Sat  Away
#                   9  2018-09-18  19:45 (20:45)   Matchweek 8  Tue  Home
#                   10 2018-09-22  15:00 (16:00)   Matchweek 9  Sat  Home
#                   11 2018-09-28  20:00 (21:00)  Matchweek 10  Fri  Away
#                   12 2018-10-02  19:45 (20:45)  Matchweek 11  Tue  Home
# ...                         ...            ...           ...  ...   ...
# Wycombe Wanderers 45 2021-04-17  12:30 (13:30)  Matchweek 42  Sat  Away
#                   46 2021-04-21  19:00 (20:00)  Matchweek 43  Wed  Home
#                   47 2021-04-24  15:00 (16:00)  Matchweek 44  Sat  Away
#                   48 2021-05-01  15:00 (16:00)  Matchweek 45  Sat  Home
#                   49 2021-05-08  12:30 (13:30)  Matchweek 46  Sat  Away
#
#                      result  gf  ga        opponent  xg_x  ...  gf_rolling  \
# team                                                       ...
# Aston Villa       8       D   1   1       Blackburn   0.9  ...    1.833333
#                   9       W   2   0   Rotherham Utd   1.4  ...    1.500000
#                   10      L   1   2  Sheffield Weds   1.5  ...    1.333333
#                   11      D   1   1    Bristol City   0.5  ...    1.333333
#                   12      D   3   3         Preston   1.5  ...    1.166667
# ...                     ...  ..  ..             ...   ...  ...         ...
# Wycombe Wanderers 45      D   2   2    Swansea City   1.4  ...    1.166667
#                   46      W   2   1    Bristol City   2.4  ...    1.333333
#                   47      L   1   2    Cardiff City   1.5  ...    1.500000
#                   48      W   1   0     Bournemouth   0.6  ...    1.666667
#                   49      W   3   0   Middlesbrough   1.9  ...    1.666667
#
#                       ga_rolling  xg_x_rolling xga_rolling sh_rolling  \
# team
# Aston Villa       8     1.833333      1.066667    1.233333  13.833333
#                   9     1.833333      1.066667    1.266667  14.833333
#                   10    1.500000      0.983333    1.166667  14.333333
#                   11    1.666667      1.150000    1.250000  15.666667
#                   12    1.500000      1.066667    1.033333  14.833333
# ...                          ...           ...         ...        ...
# Wycombe Wanderers 45    1.000000      1.066667    1.450000   9.333333
#                   46    1.333333      1.150000    1.816667   9.333333
#                   47    1.000000      1.350000    1.500000  11.833333
#                   48    1.333333      1.500000    1.416667  12.833333
#                   49    1.333333      1.300000    1.466667  13.500000
#
#                      sot_rolling dist_rolling fk_rolling  pk_rolling  \
# team
# Aston Villa       8     5.333333    18.433333   0.500000    0.000000
#                   9     5.333333    18.600000   0.500000    0.000000
#                   10    5.000000    18.116667   0.666667    0.000000
#                   11    5.000000    18.600000   0.833333    0.000000
#                   12    4.500000    19.316667   0.833333    0.000000
# ...                          ...          ...        ...         ...
# Wycombe Wanderers 45    3.166667    18.166667   0.333333    0.166667
#                   46    3.000000    17.716667   0.333333    0.166667
#                   47    3.333333    16.866667   0.000000    0.333333
#                   48    3.333333    17.616667   0.000000    0.500000
#                   49    3.500000    19.366667   0.166667    0.500000
#
#                       pkatt_rolling
# team
# Aston Villa       8        0.000000
#                   9        0.000000
#                   10       0.000000
#                   11       0.000000
#                   12       0.000000
# ...                             ...
# Wycombe Wanderers 45       0.166667
#                   46       0.166667
#                   47       0.333333
#                   48       0.500000
#                   49       0.500000
#
# [7526 rows x 43 columns]

# %%
# We've now created a second index level called "team" which we don't need so we'll remove that.

matches_rolling = matches_rolling.droplevel("team")

# %%
# Values for the one index column that remains are not unique, they are repeated for each team.

matches_rolling.tail(50)
# Out:
#          date           time         round  day venue result  gf  ga  \
# 40 2023-03-14  19:45 (20:45)  Matchweek 37  Tue  Home      D   1   1
# 41 2023-03-18  15:00 (16:00)  Matchweek 38  Sat  Away      D   1   1
# 42 2023-04-01  15:00 (16:00)  Matchweek 39  Sat  Home      W   1   0
# 43 2023-04-07  15:00 (16:00)  Matchweek 40  Fri  Away      L   0   1
# 44 2023-04-10  15:00 (16:00)  Matchweek 41  Mon  Home      L   0   2
# 45 2023-04-15  15:00 (16:00)  Matchweek 42  Sat  Away      L   0   1
# 46 2023-04-18  19:45 (20:45)  Matchweek 43  Tue  Away      W   1   0
# 47 2023-04-22  15:00 (16:00)  Matchweek 44  Sat  Home      W   2   1
# 48 2023-04-29  15:00 (16:00)  Matchweek 45  Sat  Away      D   1   1
# 49 2023-05-08  15:00 (16:00)  Matchweek 46  Mon  Home      D   0   0
# 7  2020-10-24  15:00 (16:00)   Matchweek 7  Sat  Away      L   1   2
# 8  2020-10-27  19:45 (20:45)   Matchweek 8  Tue  Home      D   1   1
# 9  2020-10-31  15:00 (16:00)   Matchweek 9  Sat  Home      W   1   0
# 10 2020-11-04  19:45 (20:45)  Matchweek 10  Wed  Away      W   2   1
# 11 2020-11-07  15:00 (16:00)  Matchweek 11  Sat  Away      L   0   2
# 12 2020-11-21  15:00 (16:00)  Matchweek 12  Sat  Home      D   0   0
# 13 2020-11-24  19:00 (20:00)  Matchweek 13  Tue  Home      D   0   0
# 14 2020-11-28  15:00 (16:00)  Matchweek 14  Sat  Away      D   1   1
# 15 2020-12-02  19:45 (20:45)  Matchweek 15  Wed  Home      L   0   1
# 16 2020-12-05  15:00 (16:00)  Matchweek 16  Sat  Away      D   2   2
# 17 2020-12-09  19:45 (20:45)  Matchweek 17  Wed  Away      L   1   2
# 18 2020-12-12  15:00 (16:00)  Matchweek 18  Sat  Home      L   1   2
# 19 2020-12-15  19:45 (20:45)  Matchweek 19  Tue  Away      L   0   1
# 20 2020-12-19  15:00 (16:00)  Matchweek 20  Sat  Home      D   1   1
# 21 2020-12-26  15:00 (16:00)  Matchweek 21  Sat  Away      L   1   2
# 22 2020-12-29  19:45 (20:45)  Matchweek 22  Tue  Home      W   2   1
# 23 2021-01-02  15:00 (16:00)  Matchweek 23  Sat  Home      L   1   3
# 26 2021-01-30  15:00 (16:00)  Matchweek 27  Sat  Away      L   2   7
# 27 2021-02-02  19:00 (20:00)  Matchweek 26  Tue  Home      D   0   0
# 28 2021-02-06  15:00 (16:00)  Matchweek 28  Sat  Home      L   0   3
# 29 2021-02-09  19:00 (20:00)  Matchweek 25  Tue  Away      L   0   2
# 31 2021-02-13  15:00 (16:00)  Matchweek 29  Sat  Away      W   3   2
# 32 2021-02-16  19:45 (20:45)  Matchweek 30  Tue  Home      L   1   2
# 33 2021-02-20  15:00 (16:00)  Matchweek 31  Sat  Away      D   0   0
# 34 2021-02-23  19:45 (20:45)  Matchweek 32  Tue  Home      W   1   0
# 35 2021-02-28  12:00 (13:00)  Matchweek 33  Sun  Home      L   0   2
# 36 2021-03-03  19:00 (20:00)  Matchweek 34  Wed  Away      L   0   2
# 37 2021-03-06  15:00 (16:00)  Matchweek 35  Sat  Away      L   0   2
# 38 2021-03-09  19:00 (20:00)  Matchweek 24  Tue  Away      L   0   1
# 39 2021-03-13  15:00 (16:00)  Matchweek 36  Sat  Home      W   1   0
# 40 2021-03-17  19:00 (20:00)  Matchweek 37  Wed  Home      L   1   3
# 41 2021-03-20  15:00 (16:00)  Matchweek 38  Sat  Away      D   0   0
# 42 2021-04-02  15:00 (16:00)  Matchweek 39  Fri  Home      W   1   0
# 43 2021-04-05  15:00 (16:00)  Matchweek 40  Mon  Away      W   3   0
# 44 2021-04-10  15:00 (16:00)  Matchweek 41  Sat  Home      L   1   3
# 45 2021-04-17  12:30 (13:30)  Matchweek 42  Sat  Away      D   2   2
# 46 2021-04-21  19:00 (20:00)  Matchweek 43  Wed  Home      W   2   1
# 47 2021-04-24  15:00 (16:00)  Matchweek 44  Sat  Away      L   1   2
# 48 2021-05-01  15:00 (16:00)  Matchweek 45  Sat  Home      W   1   0
# 49 2021-05-08  12:30 (13:30)  Matchweek 46  Sat  Away      W   3   0
#
#            opponent  xg_x  ...  gf_rolling  ga_rolling  xg_x_rolling  \
# 40    Coventry City   0.9  ...    0.500000    1.333333      0.700000
# 41          Watford   0.3  ...    0.500000    1.333333      0.666667
# 42              QPR   1.2  ...    0.666667    1.500000      0.550000
# 43    Sheffield Utd   1.2  ...    0.666667    1.166667      0.650000
# 44     Swansea City   0.9  ...    0.500000    1.166667      0.766667
# 45        Blackpool   1.1  ...    0.500000    1.333333      0.833333
# 46       Stoke City   0.7  ...    0.500000    1.000000      0.933333
# 47         Millwall   1.8  ...    0.500000    0.833333      0.900000
# 48          Reading   1.7  ...    0.666667    0.833333      1.150000
# 49    Rotherham Utd   1.0  ...    0.666667    1.000000      1.233333
# 7      Norwich City   0.9  ...    0.166667    2.166667      0.833333
# 8           Watford   1.8  ...    0.333333    2.333333      0.616667
# 9    Sheffield Weds   0.7  ...    0.500000    1.666667      0.850000
# 10  Birmingham City   1.3  ...    0.666667    1.333333      0.916667
# 11  Nott'ham Forest   0.7  ...    1.000000    1.166667      1.100000
# 12        Brentford   0.5  ...    0.833333    1.166667      0.966667
# 13     Huddersfield   0.6  ...    0.833333    1.000000      0.983333
# 14     Derby County   1.3  ...    0.666667    0.666667      0.933333
# 15       Stoke City   0.4  ...    0.666667    0.666667      0.850000
# 16          Preston   2.0  ...    0.500000    0.833333      0.800000
# 17         Barnsley   1.0  ...    0.500000    1.000000      0.916667
# 18    Coventry City   1.5  ...    0.666667    1.000000      0.966667
# 19      Bournemouth   0.5  ...    0.833333    1.333333      1.133333
# 20              QPR   2.0  ...    0.833333    1.500000      1.116667
# 21     Bristol City   0.6  ...    0.833333    1.500000      1.233333
# 22     Cardiff City   1.2  ...    1.000000    1.666667      1.266667
# 23    Middlesbrough   0.7  ...    1.000000    1.500000      1.133333
# 26        Brentford   1.0  ...    1.000000    1.666667      1.083333
# 27  Birmingham City   0.4  ...    1.166667    2.500000      1.000000
# 28  Nott'ham Forest   0.6  ...    1.166667    2.333333      0.983333
# 29   Sheffield Weds   0.6  ...    1.000000    2.666667      0.750000
# 31     Huddersfield   1.9  ...    0.833333    2.666667      0.750000
# 32     Derby County   1.6  ...    1.000000    2.833333      0.866667
# 33         Millwall   0.6  ...    1.000000    2.666667      1.016667
# 34          Reading   1.5  ...    0.666667    1.500000      0.950000
# 35     Norwich City   0.5  ...    0.833333    1.500000      1.133333
# 36          Watford   0.3  ...    0.833333    1.333333      1.116667
# 37       Stoke City   0.8  ...    0.833333    1.333333      1.066667
# 38              QPR   0.8  ...    0.333333    1.333333      0.883333
# 39          Preston   0.9  ...    0.166667    1.166667      0.750000
# 40         Barnsley   1.2  ...    0.333333    1.166667      0.800000
# 41    Coventry City   0.6  ...    0.333333    1.666667      0.750000
# 42        Blackburn   1.8  ...    0.333333    1.333333      0.766667
# 43    Rotherham Utd   0.9  ...    0.500000    1.000000      1.016667
# 44       Luton Town   1.0  ...    1.000000    0.666667      1.033333
# 45     Swansea City   1.4  ...    1.166667    1.000000      1.066667
# 46     Bristol City   2.4  ...    1.333333    1.333333      1.150000
# 47     Cardiff City   1.5  ...    1.500000    1.000000      1.350000
# 48      Bournemouth   0.6  ...    1.666667    1.333333      1.500000
# 49    Middlesbrough   1.9  ...    1.666667    1.333333      1.300000
#
#    xga_rolling sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  \
# 40    1.516667   9.000000    3.166667    18.166667   0.333333    0.000000
# 41    1.833333   9.000000    3.500000    18.833333   0.333333    0.000000
# 42    1.933333   8.166667    2.833333    19.150000   0.166667    0.000000
# 43    1.883333   7.000000    2.833333    19.666667   0.333333    0.166667
# 44    2.216667   7.333333    2.500000    19.266667   0.333333    0.166667
# 45    2.133333   7.000000    2.500000    18.150000   0.333333    0.166667
# 46    1.683333   8.833333    2.500000    18.566667   0.333333    0.166667
# 47    1.350000   8.333333    2.000000    18.900000   0.500000    0.166667
# 48    1.300000  10.000000    2.000000    17.716667   0.666667    0.166667
# 49    1.516667  10.666667    2.000000    15.666667   0.333333    0.000000
# 7     2.200000   8.500000    2.166667    19.433333   0.500000    0.000000
# 8     2.400000   8.166667    2.000000    18.700000   0.333333    0.000000
# 9     1.966667   9.000000    2.833333    17.800000   0.333333    0.000000
# 10    1.500000   9.500000    3.000000    16.850000   0.166667    0.000000
# 11    1.283333  10.833333    3.333333    16.350000   0.333333    0.000000
# 12    1.150000  11.333333    3.666667    16.150000   0.166667    0.000000
# 13    1.133333  11.500000    3.666667    15.616667   0.333333    0.000000
# 14    0.933333  11.666667    3.500000    16.483333   0.333333    0.000000
# 15    1.216667  10.666667    2.833333    15.883333   0.333333    0.000000
# 16    1.366667  10.166667    2.500000    16.266667   0.333333    0.000000
# 17    1.400000  10.833333    2.500000    16.216667   0.500000    0.000000
# 18    1.366667   9.666667    1.833333    16.733333   0.500000    0.166667
# 19    1.400000   9.500000    1.666667    16.666667   0.333333    0.333333
# 20    1.783333   9.666667    2.000000    17.000000   0.333333    0.333333
# 21    1.433333  10.833333    2.666667    17.183333   0.333333    0.333333
# 22    1.333333  11.666667    2.666667    17.250000   0.333333    0.333333
# 23    1.366667  10.833333    2.833333    17.733333   0.000000    0.333333
# 26    1.616667  12.000000    3.000000    17.450000   0.166667    0.166667
# 27    2.200000  12.166667    3.500000    16.233333   0.166667    0.000000
# 28    1.933333  11.166667    3.333333    16.716667   0.333333    0.000000
# 29    2.200000  10.500000    2.500000    17.900000   0.500000    0.000000
# 31    2.283333   9.333333    2.666667    17.450000   0.666667    0.000000
# 32    2.216667   9.833333    2.833333    16.850000   0.666667    0.166667
# 33    1.900000  10.500000    3.333333    17.750000   0.666667    0.333333
# 34    1.300000  10.166667    3.000000    19.066667   0.833333    0.333333
# 35    1.416667  10.833333    3.333333    18.766667   0.666667    0.333333
# 36    1.533333  10.333333    3.333333    19.100000   0.500000    0.333333
# 37    1.583333  10.500000    3.000000    19.783333   0.500000    0.333333
# 38    1.666667  10.166667    2.500000    19.666667   0.500000    0.166667
# 39    1.766667   9.333333    2.000000    18.933333   0.333333    0.000000
# 40    1.716667  10.333333    2.333333    18.483333   0.166667    0.000000
# 41    1.766667  10.166667    2.166667    18.400000   0.500000    0.000000
# 42    1.466667  10.166667    2.166667    17.300000   0.500000    0.000000
# 43    1.516667  10.500000    2.500000    15.983333   0.333333    0.000000
# 44    1.433333  10.166667    3.000000    17.083333   0.333333    0.000000
# 45    1.450000   9.333333    3.166667    18.166667   0.333333    0.166667
# 46    1.816667   9.333333    3.000000    17.716667   0.333333    0.166667
# 47    1.500000  11.833333    3.333333    16.866667   0.000000    0.333333
# 48    1.416667  12.833333    3.333333    17.616667   0.000000    0.500000
# 49    1.466667  13.500000    3.500000    19.366667   0.166667    0.500000
#
#     pkatt_rolling
# 40       0.000000
# 41       0.000000
# 42       0.000000
# 43       0.166667
# 44       0.166667
# 45       0.166667
# 46       0.166667
# 47       0.166667
# 48       0.166667
# 49       0.000000
# 7        0.000000
# 8        0.000000
# 9        0.000000
# 10       0.000000
# 11       0.000000
# 12       0.000000
# 13       0.000000
# 14       0.000000
# 15       0.000000
# 16       0.000000
# 17       0.000000
# 18       0.166667
# 19       0.333333
# 20       0.333333
# 21       0.333333
# 22       0.333333
# 23       0.333333
# 26       0.166667
# 27       0.000000
# 28       0.000000
# 29       0.000000
# 31       0.000000
# 32       0.166667
# 33       0.333333
# 34       0.333333
# 35       0.500000
# 36       0.500000
# 37       0.500000
# 38       0.333333
# 39       0.166667
# 40       0.166667
# 41       0.000000
# 42       0.000000
# 43       0.000000
# 44       0.000000
# 45       0.166667
# 46       0.166667
# 47       0.333333
# 48       0.500000
# 49       0.500000
#
# [50 rows x 43 columns]

# %%
# We'll reset the index to be a simple range index.

matches_rolling.index = range(matches_rolling.shape[0])

# %%
# Now each row has a unique index value once again.

matches_rolling
# Out:
#            date           time         round  day venue result  gf  ga  \
# 0    2018-09-15  17:30 (18:30)   Matchweek 7  Sat  Away      D   1   1
# 1    2018-09-18  19:45 (20:45)   Matchweek 8  Tue  Home      W   2   0
# 2    2018-09-22  15:00 (16:00)   Matchweek 9  Sat  Home      L   1   2
# 3    2018-09-28  20:00 (21:00)  Matchweek 10  Fri  Away      D   1   1
# 4    2018-10-02  19:45 (20:45)  Matchweek 11  Tue  Home      D   3   3
# ...         ...            ...           ...  ...   ...    ...  ..  ..
# 7521 2021-04-17  12:30 (13:30)  Matchweek 42  Sat  Away      D   2   2
# 7522 2021-04-21  19:00 (20:00)  Matchweek 43  Wed  Home      W   2   1
# 7523 2021-04-24  15:00 (16:00)  Matchweek 44  Sat  Away      L   1   2
# 7524 2021-05-01  15:00 (16:00)  Matchweek 45  Sat  Home      W   1   0
# 7525 2021-05-08  12:30 (13:30)  Matchweek 46  Sat  Away      W   3   0
#
#             opponent  xg_x  ...  gf_rolling  ga_rolling  xg_x_rolling  \
# 0          Blackburn   0.9  ...    1.833333    1.833333      1.066667
# 1      Rotherham Utd   1.4  ...    1.500000    1.833333      1.066667
# 2     Sheffield Weds   1.5  ...    1.333333    1.500000      0.983333
# 3       Bristol City   0.5  ...    1.333333    1.666667      1.150000
# 4            Preston   1.5  ...    1.166667    1.500000      1.066667
# ...              ...   ...  ...         ...         ...           ...
# 7521    Swansea City   1.4  ...    1.166667    1.000000      1.066667
# 7522    Bristol City   2.4  ...    1.333333    1.333333      1.150000
# 7523    Cardiff City   1.5  ...    1.500000    1.000000      1.350000
# 7524     Bournemouth   0.6  ...    1.666667    1.333333      1.500000
# 7525   Middlesbrough   1.9  ...    1.666667    1.333333      1.300000
#
#      xga_rolling sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  \
# 0       1.233333  13.833333    5.333333    18.433333   0.500000    0.000000
# 1       1.266667  14.833333    5.333333    18.600000   0.500000    0.000000
# 2       1.166667  14.333333    5.000000    18.116667   0.666667    0.000000
# 3       1.250000  15.666667    5.000000    18.600000   0.833333    0.000000
# 4       1.033333  14.833333    4.500000    19.316667   0.833333    0.000000
# ...          ...        ...         ...          ...        ...         ...
# 7521    1.450000   9.333333    3.166667    18.166667   0.333333    0.166667
# 7522    1.816667   9.333333    3.000000    17.716667   0.333333    0.166667
# 7523    1.500000  11.833333    3.333333    16.866667   0.000000    0.333333
# 7524    1.416667  12.833333    3.333333    17.616667   0.000000    0.500000
# 7525    1.466667  13.500000    3.500000    19.366667   0.166667    0.500000
#
#       pkatt_rolling
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.000000
# ...             ...
# 7521       0.166667
# 7522       0.166667
# 7523       0.333333
# 7524       0.500000
# 7525       0.500000
#
# [7526 rows x 43 columns]

# %% [markdown]
# # Retraining our Model
#
# Now we have a new set of rolling averages columns, we can add these to our existing predictors.

# %%
updated_predictors = predictors + new_cols

# %%
# We create a function that includes everything we need to make predictions.

def make_predictions(data, predictors):
    train = data[data["date"] < '2025-01-01']
    test = data[data["date"] >= '2025-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, updated_predictors)

# %%
precision
# Out:
# 0.5571428571428572

# %% [markdown]
# Our **precision** now improves, going from **40%** to **56%**
#
# We can look at this more closely by looking at the ``combined`` values.

# %%
combined
# Out:
#       actual  predicted
# 740        0          0
# 741        0          1
# 742        1          0
# 743        0          0
# 744        0          0
# ...      ...        ...
# 7349       1          0
# 7350       0          0
# 7351       0          0
# 7352       0          0
# 7353       1          0
#
# [546 rows x 2 columns]

# %% [markdown]
# However, ``combined`` doesn't give us any information for each match, so we can't see how well we're doing for each team.
#
# We can fix this by merging that extra information in a new copy of ``combined``

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

combined.head()
# Out:
#      actual  predicted       date              team       opponent result
# 740       0          0 2025-01-01  Blackburn Rovers   Leeds United      D
# 741       0          1 2025-01-04  Blackburn Rovers        Burnley      L
# 742       1          0 2025-01-15  Blackburn Rovers     Portsmouth      W
# 743       0          0 2025-01-18  Blackburn Rovers  Oxford United      L
# 744       0          0 2025-01-21  Blackburn Rovers  Coventry City      L

# %% [markdown]
# # Combining Home Team and Away Team Predictions
#
# The final thing we'll do is look at how well our model did at correctly predicting the outcome for both teams in a match.
#
# In our dataset we have data for **both** teams in **every** match and so **two separate rows** of data for **each** match.
#
# Our model therefore might have predicted **both** teams to win in any given match.
#
# We can therefore combine the predictions for both teams in each match to resolve any issues.
#
# In order to do this we need to replace some of the team names to their short-hand form so that they are matched with their short-hand forms in the ``opponent`` column.
#
# To do that we'll create a dictionary that includes all the teams that require editting in the ``team`` column and then use the Pandas ``map`` function with that dictionary.

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key # Return the key if it's not found in the dictionary

map_values = {
    "West Bromwich Albion": "West Brom",
    "Queens Park Rangers": "QPR",
    "Preston North End": "Preston",
    "Leeds United": "Leeds Utd",
    "Sheffield United": "Sheffield Utd",
    "Sheffield Wednesday": "Sheffield Weds",
    "Rotherham United": "Rotherham Utd",
    "Wolverhampton Wanderers": "Wolves",
    "Newcastle United": "Newcastle Utd",
    "Blackburn Rovers": "Blackburn",
    "Brighton and Hove Albion": "Brighton",
    "Peterborough Utd": "P'borough Utd",
    "Charlton Athletic": "Charlton Ath",
    "Peterborough United": "P'borough Utd",
    "Wycome Wanderers": "Wycome",
    "Bolton Wanderers": "Bolton",
    "Huddersfield Town": "Huddersfield",
    "Nottingham Forest": "Nott'ham Forest"
}


# Create an instance of MissingDict with the mapping values as well as a default behaviour for missing keys
mapping = MissingDict(**map_values)

# %%
# Test mapping to ensure a team that doesn't need changing is returned as-is.
mapping["Hull City"]
# Out:
# 'Hull City'

# %%
# Test the mapping to ensure a team that does need changing to it's short-hand format is correctly mapped.
mapping["Queens Park Rangers"]
# Out:
# 'QPR'

# %% [markdown]
# We can then use ``mapping`` with the Pandas ``map`` method.

# %%
combined["new_team"] = combined["team"].map(mapping)

# %% [markdown]
# If we had passed the basic ``map_values`` dictionary to the Pandas ``map`` method, the ``new_team`` column would be empty for Hull City etc. because they don't exist in the dictionary.

# %%
combined[combined["team"] == "Hull City"]
# Out:
#       actual  predicted       date       team         opponent result  \
# 2849       0          0 2025-01-01  Hull City    Middlesbrough      L
# 2850       0          0 2025-01-04  Hull City     Leeds United      D
# 2851       1          0 2025-01-18  Hull City         Millwall      W
# 2852       0          0 2025-01-21  Hull City              QPR      L
# 2853       1          0 2025-01-24  Hull City    Sheffield Utd      W
# 2854       0          0 2025-02-01  Hull City       Stoke City      L
# 2855       0          0 2025-02-12  Hull City          Burnley      L
# 2856       0          0 2025-02-15  Hull City     Norwich City      D
# 2857       1          0 2025-02-22  Hull City       Sunderland      W
# 2858       0          0 2025-02-25  Hull City     Cardiff City      L
# 2859       1          0 2025-03-04  Hull City  Plymouth Argyle      W
# 2860       0          0 2025-03-08  Hull City     Bristol City      D
# 2861       1          1 2025-03-12  Hull City    Oxford United      W
# 2862       0          0 2025-03-15  Hull City        West Brom      D
# 2863       0          0 2025-03-29  Hull City       Luton Town      L
# 2864       1          0 2025-04-05  Hull City   Sheffield Weds      W
# 2865       0          0 2025-04-08  Hull City          Watford      L
# 2866       0          0 2025-04-14  Hull City    Coventry City      D
# 2867       0          0 2025-04-18  Hull City     Swansea City      L
# 2868       1          0 2025-04-21  Hull City          Preston      W
# 2869       0          0 2025-04-26  Hull City     Derby County      L
# 2870       0          0 2025-05-03  Hull City       Portsmouth      D
#
#        new_team
# 2849  Hull City
# 2850  Hull City
# 2851  Hull City
# 2852  Hull City
# 2853  Hull City
# 2854  Hull City
# 2855  Hull City
# 2856  Hull City
# 2857  Hull City
# 2858  Hull City
# 2859  Hull City
# 2860  Hull City
# 2861  Hull City
# 2862  Hull City
# 2863  Hull City
# 2864  Hull City
# 2865  Hull City
# 2866  Hull City
# 2867  Hull City
# 2868  Hull City
# 2869  Hull City
# 2870  Hull City

# %% [markdown]
# We can now use ``new_team`` to merge ``combined`` with itself.

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                team_x     opponent_x  \
# 0           0            0 2025-01-01      Blackburn Rovers   Leeds United
# 1           0            1 2025-01-04      Blackburn Rovers        Burnley
# 2           1            0 2025-01-15      Blackburn Rovers     Portsmouth
# 3           0            0 2025-01-18      Blackburn Rovers  Oxford United
# 4           0            0 2025-01-21      Blackburn Rovers  Coventry City
# ..        ...          ...        ...                   ...            ...
# 519         1            0 2025-04-12  West Bromwich Albion        Watford
# 520         0            0 2025-04-18  West Bromwich Albion  Coventry City
# 521         0            0 2025-04-21  West Bromwich Albion   Derby County
# 522         0            0 2025-04-26  West Bromwich Albion   Cardiff City
# 523         1            0 2025-05-03  West Bromwich Albion     Luton Town
#
#     result_x new_team_x  actual_y  predicted_y         team_y opponent_y  \
# 0          D  Blackburn         0            1   Leeds United  Blackburn
# 1          L  Blackburn         1            1        Burnley  Blackburn
# 2          W  Blackburn         0            0     Portsmouth  Blackburn
# 3          L  Blackburn         1            0  Oxford United  Blackburn
# 4          L  Blackburn         1            0  Coventry City  Blackburn
# ..       ...        ...       ...          ...            ...        ...
# 519        W  West Brom         0            0        Watford  West Brom
# 520        L  West Brom         1            1  Coventry City  West Brom
# 521        L  West Brom         1            0   Derby County  West Brom
# 522        D  West Brom         0            0   Cardiff City  West Brom
# 523        W  West Brom         0            0     Luton Town  West Brom
#
#     result_y     new_team_y
# 0          D      Leeds Utd
# 1          W        Burnley
# 2          L     Portsmouth
# 3          W  Oxford United
# 4          W  Coventry City
# ..       ...            ...
# 519        L        Watford
# 520        W  Coventry City
# 521        W   Derby County
# 522        D   Cardiff City
# 523        L     Luton Town
#
# [524 rows x 13 columns]

# %% [markdown]
# We can now look at all the games where the home team were predicted to win and the away team were predicted to not win and get the value count of home wins.

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    27
# 0    22
# Name: count, dtype: int64

# %%
27 / (27 + 22)
# Out:
# 0.5510204081632653

# %% [markdown]
# Precision for home wins is **55%**
#
# We can then do the same for games where the **home** team were predicted to **not win** and the **away** team **were** predicted win and get the value count of away wins.

# %%
merged[(merged["predicted_x"] == 0) & (merged["predicted_y"] == 1)]["actual_y"].value_counts()
# Out:
# actual_y
# 1    35
# 0    27
# Name: count, dtype: int64

# %%
35 / (35 + 27)
# Out:
# 0.5645161290322581

# %% [markdown]
# Precision for away wins is **56%**
